# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Read file
df = pd.read_csv('WorldSustainabilityDataset.csv')
df.head()
# Out:
#   Country Name Country Code  Year  \
# 0        Aruba          ABW  2000
# 1        Aruba          ABW  2001
# 2        Aruba          ABW  2002
# 3        Aruba          ABW  2003
# 4        Aruba          ABW  2004
#
#    Access to electricity (% of population) - EG.ELC.ACCS.ZS  \
# 0                                          91.660398
# 1                                         100.000000
# 2                                         100.000000
# 3                                         100.000000
# 4                                         100.000000
#
#    Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Adjusted net savings, excluding particulate emission damage (% of GNI) - NY.ADJ.SVNX.GN.ZS  \
# 0                                          15.392211
# 1                                          11.491930
# 2                                           3.893620
# 3                                           6.713863
# 4                                           9.801576
#
#    Adjusted savings: carbon dioxide damage (% of GNI) - NY.ADJ.DCO2.GN.ZS  \
# 0                                           2.389134
# 1                                           2.509046
# 2                                           2.721385
# 3                                           2.733676
# 4                                           2.678363
#
#    Adjusted savings: natural resources depletion (% of GNI) - NY.ADJ.DRES.GN.ZS  \
# 0                                           0.000190
# 1                                           0.000214
# 2                                           0.000223
# 3                                           0.000243
# 4                                           0.000256
#
#    Adjusted savings: net forest depletion (% of GNI) - NY.ADJ.DFOR.GN.ZS  \
# 0                                           0.000190
# 1                                           0.000214
# 2                                           0.000223
# 3                                           0.000243
# 4                                           0.000256
#
#    Adjusted savings: particulate emission damage (% of GNI) - NY.ADJ.DPEM.GN.ZS  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ...  Gini index (World Bank estimate) - SI.POV.GINI  \
# 0  ...                                             NaN
# 1  ...                                             NaN
# 2  ...                                             NaN
# 3  ...                                             NaN
# 4  ...                                             NaN
#
#    Income Classification (World Bank Definition)  \
# 0                                    High income
# 1                                    High income
# 2                                    High income
# 3                                    High income
# 4                                    High income
#
#    Individuals using the Internet (% of population) - IT.NET.USER.ZS  \
# 0                                                NaN
# 1                                               17.1
# 2                                               18.8
# 3                                               20.8
# 4                                               23.0
#
#    Life expectancy at birth, total (years) - SP.DYN.LE00.IN  \
# 0                                                NaN
# 1                                             73.853
# 2                                             73.937
# 3                                             74.038
# 4                                             74.156
#
#    Population, total - SP.POP.TOTL  Regime Type (RoW Measure Definition)  \
# 0                              NaN                                   NaN
# 1                          92892.0                                   NaN
# 2                          94992.0                                   NaN
# 3                          97016.0                                   NaN
# 4                          98744.0                                   NaN
#
#    Rural population (% of total population) - SP.RUR.TOTL.ZS  \
# 0                                             53.283
# 1                                             53.661
# 2                                             54.028
# 3                                             54.394
# 4                                             54.760
#
#    Total natural resources rents (% of GDP) - NY.GDP.TOTL.RT.ZS  \
# 0                                                NaN
# 1                                           0.000712
# 2                                           0.000657
# 3                                           0.000700
# 4                                           0.000685
#
#    Urban population (% of total population) - SP.URB.TOTL.IN.ZS  \
# 0                                                NaN
# 1                                             46.339
# 2                                             45.972
# 3                                             45.606
# 4                                             45.240
#
#    World Regions (UN SDG Definition)
# 0        Latin America and Caribbean
# 1        Latin America and Caribbean
# 2        Latin America and Caribbean
# 3        Latin America and Caribbean
# 4        Latin America and Caribbean
#
# [5 rows x 54 columns]

# %%
# Get more info about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3287 entries, 0 to 3286
# Data columns (total 54 columns):
#  #   Column                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                        --------------  -----
#  0   Country Name                                                                                  3287 non-null   object
#  1   Country Code                                                                                  3287 non-null   object
#  2   Year                                                                                          3287 non-null   int64
#  3   Access to electricity (% of population) - EG.ELC.ACCS.ZS                                      3193 non-null   float64
#  4   Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG              2566 non-null   float64
#  5   Adjusted net savings, excluding particulate emission damage (% of GNI) - NY.ADJ.SVNX.GN.ZS    2628 non-null   float64
#  6   Adjusted savings: carbon dioxide damage (% of GNI) - NY.ADJ.DCO2.GN.ZS                        3220 non-null   float64
#  7   Adjusted savings: natural resources depletion (% of GNI) - NY.ADJ.DRES.GN.ZS                  3094 non-null   float64
#  8   Adjusted savings: net forest depletion (% of GNI) - NY.ADJ.DFOR.GN.ZS                         3111 non-null   float64
#  9   Adjusted savings: particulate emission damage (% of GNI) - NY.ADJ.DPEM.GN.ZS                  3099 non-null   float64
#  10  Automated teller machines (ATMs) (per 100,000 adults) - FB.ATM.TOTL.P5                        2285 non-null   float64
#  11  Broad money (% of GDP) - FM.LBL.BMNY.GD.ZS                                                    2777 non-null   float64
#  12  Children out of school (% of primary school age) - SE.PRM.UNER.ZS                             2225 non-null   float64
#  13  Compulsory education, duration (years) - SE.COM.DURS                                          2979 non-null   float64
#  14  Cost of business start-up procedures, female (% of GNI per capita) - IC.REG.COST.PC.FE.ZS     2501 non-null   float64
#  15  Cost of business start-up procedures, male (% of GNI per capita) - IC.REG.COST.PC.MA.ZS       2501 non-null   float64
#  16  Exports of goods and services (% of GDP) - NE.EXP.GNFS.ZS                                     3118 non-null   float64
#  17  Final consumption expenditure (% of GDP) - NE.CON.TOTL.ZS                                     3047 non-null   float64
#  18  GDP (current US$) - NY.GDP.MKTP.CD                                                            3246 non-null   float64
#  19  GDP per capita (current US$) - NY.GDP.PCAP.CD                                                 3246 non-null   float64
#  20  General government final consumption expenditure (% of GDP) - NE.CON.GOVT.ZS                  3031 non-null   float64
#  21  Gross national expenditure (% of GDP) - NE.DAB.TOTL.ZS                                        3047 non-null   float64
#  22  Gross savings (% of GDP) - NY.GNS.ICTR.ZS                                                     2774 non-null   float64
#  23  Imports of goods and services (% of GDP) - NE.IMP.GNFS.ZS                                     3118 non-null   float64
#  24  Inflation, consumer prices (annual %) - FP.CPI.TOTL.ZG                                        3083 non-null   float64
#  25  Primary completion rate, total (% of relevant age group) - SE.PRM.CMPT.ZS                     2226 non-null   float64
#  26  Proportion of seats held by women in national parliaments (%) - SG.GEN.PARL.ZS                3062 non-null   float64
#  27  Pupil-teacher ratio, primary - SE.PRM.ENRL.TC.ZS                                              2366 non-null   float64
#  28  Renewable electricity output (% of total electricity output) - EG.ELC.RNEW.ZS                 2771 non-null   float64
#  29  Renewable energy consumption (% of total final energy consumption) - EG.FEC.RNEW.ZS           3287 non-null   float64
#  30  School enrollment, preprimary (% gross) - SE.PRE.ENRR                                         2349 non-null   float64
#  31  School enrollment, primary (% gross) - SE.PRM.ENRR                                            2783 non-null   float64
#  32  School enrollment, secondary (% gross) - SE.SEC.ENRR                                          2430 non-null   float64
#  33  Trade (% of GDP) - NE.TRD.GNFS.ZS                                                             3118 non-null   float64
#  34  Women Business and the Law Index Score (scale 1-100) - SG.LAW.INDX                            3211 non-null   float64
#  35  Prevalence of undernourishment (%) - SN_ITK_DEFC - 2.1.1                                      1834 non-null   float64
#  36  Proportion of population below international poverty line (%) - SI_POV_DAY1 - 1.1.1           1304 non-null   float64
#  37  Proportion of population covered by at least a 2G mobile network (%) - IT_MOB_2GNTWK - 9.c.1  2349 non-null   float64
#  38  Proportion of population covered by at least a 3G mobile network (%) - IT_MOB_3GNTWK - 9.c.1  1357 non-null   float64
#  39  Proportion of population using basic drinking water services (%) - SP_ACS_BSRVH2O - 1.4.1     1837 non-null   float64
#  40  Unemployment rate, male (%) - SL_TLF_UEM - 8.5.2                                              1807 non-null   float64
#  41  Unemployment rate, women (%) - SL_TLF_UEM - 8.5.2                                             1806 non-null   float64
#  42  Annual production-based emissions of carbon dioxide (CO2), measured in million tonnes         3285 non-null   float64
#  43  Continent                                                                                     3285 non-null   object
#  44  Gini index (World Bank estimate) - SI.POV.GINI                                                1303 non-null   float64
#  45  Income Classification (World Bank Definition)                                                 3285 non-null   object
#  46  Individuals using the Internet (% of population) - IT.NET.USER.ZS                             2986 non-null   float64
#  47  Life expectancy at birth, total (years) - SP.DYN.LE00.IN                                      3096 non-null   float64
#  48  Population, total - SP.POP.TOTL                                                               3106 non-null   float64
#  49  Regime Type (RoW Measure Definition)                                                          3076 non-null   object
#  50  Rural population (% of total population) - SP.RUR.TOTL.ZS                                     3278 non-null   float64
#  51  Total natural resources rents (% of GDP) - NY.GDP.TOTL.RT.ZS                                  3053 non-null   float64
#  52  Urban population (% of total population) - SP.URB.TOTL.IN.ZS                                  3106 non-null   float64
#  53  World Regions (UN SDG Definition)                                                             3285 non-null   object
# dtypes: float64(47), int64(1), object(6)
# memory usage: 1.4+ MB

# %%
# keep only the relevant columns
cols_to_keep=[0,2,19,26,30,31,32,34,36,41,49,50]
df=df.iloc[:,cols_to_keep]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3287 entries, 0 to 3286
# Data columns (total 12 columns):
#  #   Column                                                                               Non-Null Count  Dtype
# ---  ------                                                                               --------------  -----
#  0   Country Name                                                                         3287 non-null   object
#  1   Year                                                                                 3287 non-null   int64
#  2   GDP per capita (current US$) - NY.GDP.PCAP.CD                                        3246 non-null   float64
#  3   Proportion of seats held by women in national parliaments (%) - SG.GEN.PARL.ZS       3062 non-null   float64
#  4   School enrollment, preprimary (% gross) - SE.PRE.ENRR                                2349 non-null   float64
#  5   School enrollment, primary (% gross) - SE.PRM.ENRR                                   2783 non-null   float64
#  6   School enrollment, secondary (% gross) - SE.SEC.ENRR                                 2430 non-null   float64
#  7   Women Business and the Law Index Score (scale 1-100) - SG.LAW.INDX                   3211 non-null   float64
#  8   Proportion of population below international poverty line (%) - SI_POV_DAY1 - 1.1.1  1304 non-null   float64
#  9   Unemployment rate, women (%) - SL_TLF_UEM - 8.5.2                                    1806 non-null   float64
#  10  Regime Type (RoW Measure Definition)                                                 3076 non-null   object
#  11  Rural population (% of total population) - SP.RUR.TOTL.ZS                            3278 non-null   float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 308.3+ KB

# %%
# shorten certain column names to make it easier for coding later
new_col_names = {'Country Name': 'Country', 
                 'GDP per capita (current US$) - NY.GDP.PCAP.CD': 'GDP Per Capita',
                 'Proportion of seats held by women in national parliaments (%) - SG.GEN.PARL.ZS': '% Women in Parliament',
                'School enrollment, preprimary (% gross) - SE.PRE.ENRR': 'PrePrimary School Enrolled%',
                 'School enrollment, primary (% gross) - SE.PRM.ENRR': 'Primary School Enrolled%',
                'School enrollment, secondary (% gross) - SE.SEC.ENRR': 'Secondary School Enrolled%',
                'Women Business and the Law Index Score (scale 1-100) - SG.LAW.INDX': 'Women Business and the Law Index',
               'Proportion of population below international poverty line (%) - SI_POV_DAY1 - 1.1.1': '% in Poverty',
                'Unemployment rate, women (%) - SL_TLF_UEM - 8.5.2':'Women Unemployment Rate%',
                'Regime Type (RoW Measure Definition)':'Regime',
                'Rural population (% of total population) - SP.RUR.TOTL.ZS':'Rural Population%'}
df=df.rename(columns=new_col_names)
df.head()
# Out:
#   Country  Year  GDP Per Capita  % Women in Parliament  \
# 0   Aruba  2000     20617.75047                    NaN
# 1   Aruba  2001     20670.36701                    NaN
# 2   Aruba  2002     20436.88713                    NaN
# 3   Aruba  2003     20833.97636                    NaN
# 4   Aruba  2004     22568.37499                    NaN
#
#    PrePrimary School Enrolled%  Primary School Enrolled%  \
# 0                    95.903038                110.788178
# 1                    97.550194                109.440964
# 2                    98.435913                111.010834
# 3                    99.622902                109.214302
# 4                    98.746521                110.839050
#
#    Secondary School Enrolled%  Women Business and the Law Index  % in Poverty  \
# 0                   96.516167                               NaN           NaN
# 1                   97.972870                               NaN           NaN
# 2                  100.520683                               NaN           NaN
# 3                   99.091171                               NaN           NaN
# 4                   97.252441                               NaN           NaN
#
#    Women Unemployment Rate% Regime  Rural Population%
# 0                       NaN    NaN             53.283
# 1                       NaN    NaN             53.661
# 2                       NaN    NaN             54.028
# 3                       NaN    NaN             54.394
# 4                       NaN    NaN             54.760

# %%
#Start cleaning data
#Check duplicates
#check NaNs
print(df.duplicated().value_counts())
print(df.isna().sum())
#There are no duplicates but a lot of missing datas! will need to deal with them when we perform analysis
# Out:
# False    3287
# dtype: int64
# Country                                0
# Year                                   0
# GDP Per Capita                        41
# % Women in Parliament                225
# PrePrimary School Enrolled%          938
# Primary School Enrolled%             504
# Secondary School Enrolled%           857
# Women Business and the Law Index      76
# % in Poverty                        1983
# Women Unemployment Rate%            1481
# Regime                               211
# Rural Population%                      9
# dtype: int64

# %%
#which years do we have the data for?
print(df['Year'].unique())


#To investigate crosssectional relationships, we'll look at the latest year (2018) data only. 
df2018=df.loc[df['Year']==2018]
print(df2018.info())

# In this subset of data, we are interested in the below data points and their relationship: 
#1. GDP per Capita and % Women in Parliament by country
#2. Group the countries by regime and compare women's rights/status/employment for each regime
#3. PrePrimary School Encorlled % and Women Unemployment Rate % and Women Business and the Law Index
# To keep only the relevant columns and drop countries/rows with missing values in those columns:
df2018_1=df2018.iloc[:,[0,2,3,4,7,9,10]].dropna().sort_values(by='GDP Per Capita',ascending=False)
print(df2018_1.info())
print(df2018_1.head())
# Out:
# [2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013
#  2014 2015 2016 2017 2018]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 173 entries, 18 to 3286
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           173 non-null    object
#  1   Year                              173 non-null    int64
#  2   GDP Per Capita                    169 non-null    float64
#  3   % Women in Parliament             168 non-null    float64
#  4   PrePrimary School Enrolled%       121 non-null    float64
#  5   Primary School Enrolled%          129 non-null    float64
#  6   Secondary School Enrolled%        112 non-null    float64
#  7   Women Business and the Law Index  169 non-null    float64
#  8   % in Poverty                      64 non-null     float64
#  9   Women Unemployment Rate%          102 non-null    float64
#  10  Regime                            162 non-null    object
#  11  Rural Population%                 172 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 17.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80 entries, 1842 to 2887
# Data columns (total 7 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           80 non-null     object
#  1   GDP Per Capita                    80 non-null     float64
#  2   % Women in Parliament             80 non-null     float64
#  3   PrePrimary School Enrolled%       80 non-null     float64
#  4   Women Business and the Law Index  80 non-null     float64
#  5   Women Unemployment Rate%          80 non-null     float64
#  6   Regime                            80 non-null     object
# dtypes: float64(5), object(2)
# memory usage: 5.0+ KB
# None
#           Country  GDP Per Capita  % Women in Parliament  \
# 1842   Luxembourg    116597.29560              20.000000
# 569   Switzerland     86429.50082              32.500000
# 2298       Norway     82267.80932              41.420118
# 1424      Ireland     79297.72920              22.151899
# 1481      Iceland     74348.36228              38.095238
#
#       PrePrimary School Enrolled%  Women Business and the Law Index  \
# 1842                    91.721870                           100.000
# 569                    102.811012                            85.625
# 2298                    96.002991                            96.875
# 1424                    93.493858                            97.500
# 1481                    95.673851                           100.000
#
#       Women Unemployment Rate%             Regime
# 1842                       5.9  Liberal Democracy
# 569                        5.1  Liberal Democracy
# 2298                       3.5  Liberal Democracy
# 1424                       5.7  Liberal Democracy
# 1481                       2.5  Liberal Democracy

# %%
#Plot 1. GDP per Capita and % Women in Parliament by country
ax = df2018_1.plot(kind='scatter',x='% Women in Parliament',y='GDP Per Capita')
ax.set_title('Country income level and political status of women')

# It doesn't look like there is an obvious correlation between the two numbers through simple visualisation.
# Perhaps surprisingly, countries with high income level doesn't necessarily translate to higher women participation in politics 
# it would be nice to see which country each dot represents? especially the outliners
ax2 = df2018_1.plot(kind='scatter',x='% Women in Parliament',y='GDP Per Capita')
df2018_1[['% Women in Parliament','GDP Per Capita','Country']].apply(lambda row: ax2.text(*row),axis=1);

# %%
# Plot 2. Group the countries by regime, and compare the various indicators
regimelist=list(df2018_1['Regime'].unique())
print (regimelist)
dfregime=df2018_1.groupby('Regime')

#Comparing the variables by regime
dfregime.agg('mean')

#plot the above in graph to better visualise the data
axes = dfregime.agg('mean').plot.bar(rot=0, subplots=True, figsize =(15,15))

#On average Liberal Democracy countries are the richest and have the highest female representation and lowest female unemployment rate.
# Out:
# ['Liberal Democracy', 'Closed Autocracy', 'Electoral Democracy', 'Electoral Autocracy']

# %%
#We can check which countries sit in each regime group
for regime in regimelist:
    print(regime, "countries:", dfregime.get_group(regime).loc[:, 'Country'])
    
# We notice that some large countries such as China and Japan are not included, due to missing data. 
#To perform a more complete analysis, ideally we need to source the missing data of these countries.
# Out:
# Liberal Democracy countries: 1842        Luxembourg
# 569        Switzerland
# 2298            Norway
# 1424           Ireland
# 1481           Iceland
# 3134     United States
# 873            Denmark
# 151          Australia
# 2811            Sweden
# 2279       Netherlands
# 170            Austria
# 1044           Finland
# 835            Germany
# 227            Belgium
# 2336       New Zealand
# 1120    United Kingdom
# 1500            Israel
# 1082            France
# 1671       Korea, Rep.
# 987              Spain
# 797             Cyprus
# 2792          Slovenia
# 2488          Portugal
# 816     Czech Republic
# 1006           Estonia
# 3115           Uruguay
# 1861            Latvia
# 455           Barbados
# 588              Chile
# 759         Costa Rica
# Name: Country, dtype: object
# Closed Autocracy countries: 2545           Qatar
# 2621    Saudi Arabia
# 2355            Oman
# 2925        Thailand
# 1557          Jordan
# 3210         Vietnam
# Name: Country, dtype: object
# Electoral Democracy countries: 2032                 Malta
# 1234                Greece
# 2773       Slovak Republic
# 1823             Lithuania
# 2849            Seychelles
# 2450                Poland
# 1329               Croatia
# 2564               Romania
# 2146             Mauritius
# 1975                Mexico
# 303               Bulgaria
# 892     Dominican Republic
# 702               Colombia
# 3248          South Africa
# 1994       North Macedonia
# 2203               Namibia
# 56                 Albania
# 1918               Moldova
# 2089              Mongolia
# 1785             Sri Lanka
# 2716           El Salvador
# 1386             Indonesia
# 740             Cabo Verde
# 417                Bolivia
# 1405                 India
# 2013                  Mali
# 265           Burkina Faso
# 1177           Gambia, The
# Name: Country, dtype: object
# Electoral Autocracy countries: 1367               Hungary
# 2184              Malaysia
# 2583    Russian Federation
# 3039                Turkey
# 2070            Montenegro
# 2735                Serbia
# 379                Belarus
# 189             Azerbaijan
# 113                Armenia
# 2431           Philippines
# 949       Egypt, Arab Rep.
# 2374              Pakistan
# 1633       Kyrgyz Republic
# 2051               Myanmar
# 2602                Rwanda
# 2887                  Chad
# Name: Country, dtype: object

# %%
#Plot 3: we also want to see if there is a relationship between GDP Per Capita, PrePrimary School Encorlled % and Women Unemployment Rate %. 
#Our hypothesis is that higher income level, better early childcare provisions should lead to higher female employment
x1=df2018_1['PrePrimary School Enrolled%']
x2=df2018_1['GDP Per Capita']
y=df2018_1['Women Unemployment Rate%']

# Create the plot
fig, (ax1, ax2) = plt.subplots(figsize=(11,4), ncols=2)

ax1.scatter(x1, y)
ax1.set_xlabel('PrePrimary School Enrolled%')
ax1.set_ylabel('Women Unemployment Rate%')

ax2.scatter(x2, y, color='red', marker='x')
ax2.set_xlabel('GDP Per Capita%')
ax2.set_ylabel('Women Unemployment Rate%')

fig.suptitle("Income, PreSchool Enrollment vs Women Unemployment", fontsize=12, x=0.44)
fig.legend(labels=["PreSchool Enrollment vs Women Unemployment", "Income vs Women Unemployment"], loc=(.68, .88));

#The graphs below do appear to support our hypothesis.

# %%
#Now that we have finished investigating the cross-country 2018 data, let's investigate some time series data
#We are interested in the relationship between 1)economic development and 2)improvement in women's economic and political opportunities
#The relevant columns are GDP Per Capita, % in Poverty, and Women Business and the Law Index. However A lot of % poverty data are missing so we decided to focus on GDP as a measurement of economic development.
print(df.info())

#To investigate the relationship between GDP growth and the Women Business and the Law index, we need the changes in these values year on year.
# We want to focus on the top three fastest growing countries from 2000-2018. We need to identify these countries.

def calculate_gdp_growth(dfi):
    dfi['start_gdp'] = dfi['GDP Per Capita'].iloc[0]
    dfi['end_gdp'] = dfi['GDP Per Capita'].iloc[-1]
    dfi['GDP 2000-2018 Growth'] = dfi['end_gdp'] / dfi['start_gdp']
    dfi['GDP Previous Year']=dfi['GDP Per Capita'].shift(1)
    dfi['GDP YoY Change']=dfi['GDP Per Capita']/dfi['GDP Previous Year']-1
    dfi['WBLI Previous Year'] = dfi['Women Business and the Law Index'].shift(1)
    dfi['WBLI YoY Change']=dfi['Women Business and the Law Index']-dfi['WBLI Previous Year']
    return dfi

df2=df.iloc[:,[0,1,2,7]].sort_values(['Country','Year'],ascending=(True,True)).groupby('Country').apply(calculate_gdp_growth).reset_index(drop=True)
print(df2.head())
print(df2.info())

top3val=list(df2.loc[df['Year']==2018]['GDP 2000-2018 Growth'].nlargest(n=3))
print(top3val)

top3countries=list(df2[ (df2['Year'] == 2018) & (df2['GDP 2000-2018 Growth'].isin(top3val)) ]['Country'])
print (top3countries)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3287 entries, 0 to 3286
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           3287 non-null   object
#  1   Year                              3287 non-null   int64
#  2   GDP Per Capita                    3246 non-null   float64
#  3   % Women in Parliament             3062 non-null   float64
#  4   PrePrimary School Enrolled%       2349 non-null   float64
#  5   Primary School Enrolled%          2783 non-null   float64
#  6   Secondary School Enrolled%        2430 non-null   float64
#  7   Women Business and the Law Index  3211 non-null   float64
#  8   % in Poverty                      1304 non-null   float64
#  9   Women Unemployment Rate%          1806 non-null   float64
#  10  Regime                            3076 non-null   object
#  11  Rural Population%                 3278 non-null   float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 308.3+ KB
# None
#    Country  Year  GDP Per Capita  Women Business and the Law Index  \
# 0  Albania  2000     1126.683318                              80.0
# 1  Albania  2001     1281.659393                              80.0
# 2  Albania  2002     1425.124849                              80.0
# 3  Albania  2003     1846.118813                              80.0
# 4  Albania  2004     2373.579844                              80.0
#
#      start_gdp      end_gdp  GDP 2000-2018 Growth  GDP Previous Year  \
# 0  1126.683318  5284.380184              4.690209                NaN
# 1  1126.683318  5284.380184              4.690209        1126.683318
# 2  1126.683318  5284.380184              4.690209        1281.659393
# 3  1126.683318  5284.380184              4.690209        1425.124849
# 4  1126.683318  5284.380184              4.690209        1846.118813
#
#    GDP YoY Change  WBLI Previous Year  WBLI YoY Change
# 0             NaN                 NaN              NaN
# 1        0.137551                80.0              0.0
# 2        0.111937                80.0              0.0
# 3        0.295408                80.0              0.0
# 4        0.285713                80.0              0.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3287 entries, 0 to 3286
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           3287 non-null   object
#  1   Year                              3287 non-null   int64
#  2   GDP Per Capita                    3246 non-null   float64
#  3   Women Business and the Law Index  3211 non-null   float64
#  4   start_gdp                         3268 non-null   float64
#  5   end_gdp                           3211 non-null   float64
#  6   GDP 2000-2018 Growth              3211 non-null   float64
#  7   GDP Previous Year                 3077 non-null   float64
#  8   GDP YoY Change                    3074 non-null   float64
#  9   WBLI Previous Year                3042 non-null   float64
#  10  WBLI YoY Change                   3042 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 282.6+ KB
# None
# [12.823608072046971, 10.399169569219861, 9.59979926631636]
# ['China', 'Moldova', 'Myanmar']

# %%
# Now we define a new dataframe with only these three countries and the two variables we are interested in.
df3 = df2[df2['Country'].isin(top3countries)].reset_index(drop=True)
df3.head()
# Out:
#   Country  Year  GDP Per Capita  Women Business and the Law Index   start_gdp  \
# 0   China  2000      959.372484                              62.5  959.372484
# 1   China  2001     1053.108243                              62.5  959.372484
# 2   China  2002     1148.508290                              65.0  959.372484
# 3   China  2003     1288.643252                              65.0  959.372484
# 4   China  2004     1508.668098                              70.0  959.372484
#
#        end_gdp  GDP 2000-2018 Growth  GDP Previous Year  GDP YoY Change  \
# 0  9976.677137              10.39917                NaN             NaN
# 1  9976.677137              10.39917         959.372484        0.097705
# 2  9976.677137              10.39917        1053.108243        0.090589
# 3  9976.677137              10.39917        1148.508290        0.122015
# 4  9976.677137              10.39917        1288.643252        0.170741
#
#    WBLI Previous Year  WBLI YoY Change
# 0                 NaN              NaN
# 1                62.5              0.0
# 2                62.5              2.5
# 3                65.0              0.0
# 4                65.0              5.0

# %%
#Now let's run to run some regression lines of the two variables per country
import seaborn as sns

for i in df3['Country'].unique():
    sns.set_style('whitegrid')
    sns.lmplot(x ='GDP YoY Change', y ='WBLI YoY Change', data = df3.loc[df3['Country']==i]).set(title=i)

#It doesn't seem like there is an obvious linear relationship between the two changes!

# %%
#Let's explore the line plots of the WBLI:
for i in df3['Country'].unique():
    sns.lmplot(x ='Year', y ='Women Business and the Law Index', data = df3.loc[df3['Country']==i]).set(title=i)

#The data is not continuous which might have resulted in the strange regression plots above. 
#In general though, these three countires that experienced strong economic growth also saw an improvement in Women's status

# %% [markdown]
# ##
